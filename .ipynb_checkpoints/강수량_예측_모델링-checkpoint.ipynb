# %%
# %pwd
# Out:
# 'C:\\Users\\k0e1s'

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv("OneDrive/바탕 화면/날씨/rainfall_train.csv")
df1 = df1.drop('Unnamed: 0', axis=1)
df1
# Out:
#         rainfall_train.fc_year  rainfall_train.fc_month  \
# 0                            A                        5
# 1                            A                        5
# 2                            A                        5
# 3                            A                        5
# 4                            A                        5
# ...                        ...                      ...
# 1457247                      C                        9
# 1457248                      C                        9
# 1457249                      C                        9
# 1457250                      C                        9
# 1457251                      C                        9
#
#          rainfall_train.fc_day  rainfall_train.fc_hour  \
# 0                            1                       9
# 1                            1                       9
# 2                            1                       9
# 3                            1                       9
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1457252 entries, 0 to 1457251
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   rainfall_train.fc_year         1457252 non-null  object
#  1   rainfall_train.fc_month        1457252 non-null  int64
#  2   rainfall_train.fc_day          1457252 non-null  int64
#  3   rainfall_train.fc_hour         1457252 non-null  int64
#  4   rainfall_train.stn4contest     1457252 non-null  object
#  5   rainfall_train.dh              1457252 non-null  int64
#  6   rainfall_train.ef_year         1457252 non-null  object
#  7   rainfall_train.ef_month        1457252 non-null  int64
#  8   rainfall_train.ef_day          1457252 non-null  int64
#  9   rainfall_train.ef_hour         1457252 non-null  int64
#  10  rainfall_train.v01             1457252 non-null  int64
#  11  rainfall_train.v02             1457252 non-null  int64
# ...

# %%
df1['rainfall_train.class_interval'].value_counts()
# Out:
#  0      1223315
#  5        41407
#  2        34054
#  4        33427
#  3        30692
#  6        27964
#  1        21562
#  7        21168
# -999       8490
#  8         8187
#  9         6986
# Name: rainfall_train.class_interval, dtype: int64

# %%
df1 = df1[df1['rainfall_train.class_interval'] >=0]
# 결측치 처리하는 걸로 ~ 시간 남으면 나중에 999로 바꿔서 검증해보자 !

# %% [markdown]
# ### 범주형 변수 전처리

# %%
# 더미변수처리
df1 = pd.get_dummies(df1, columns = ['rainfall_train.fc_year', 'rainfall_train.ef_year'])

# 라벨링
label1 = df1['rainfall_train.stn4contest'].unique().tolist()
df1['rainfall_train.aws'] = df1['rainfall_train.stn4contest'].map(lambda x : label1.index(x))
df1 = df1.drop('rainfall_train.stn4contest', axis=1)
df1
# Out:
#          rainfall_train.fc_month  rainfall_train.fc_day  \
# 0                              5                      1
# 1                              5                      1
# 2                              5                      1
# 3                              5                      1
# 4                              5                      1
# ...                          ...                    ...
# 1457247                        9                     30
# 1457248                        9                     30
# 1457249                        9                     30
# 1457250                        9                     30
# 1457251                        9                     30
#
#          rainfall_train.fc_hour  rainfall_train.dh  rainfall_train.ef_month  \
# 0                             9                  3                        5
# 1                             9                  6                        5
# ...

# %% [markdown]
# ### 수치형 변수 전처리

# %%
df1['rainfall_train.v01'].value_counts()
# Out:
# 0     222544
# 2      51480
# 1      37187
# 4      36970
# 6      30508
#        ...
# 89      4579
# 97      4466
# 91      4266
# 93      4156
# 95      4130
# Name: rainfall_train.v01, Length: 101, dtype: int64

# %%
# 이상치 확인
for col in df1:
    plt.figure(figsize=(10, 8))
    sns.boxplot(df1[col])
    plt.title(col)
    plt.show()
# Out:
# C:\Users\k0e1s\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\k0e1s\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\k0e1s\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# 이상치 처리
num_col = ['rainfall_train.v01', 'rainfall_train.v02', 'rainfall_train.v03', 'rainfall_train.v04', 'rainfall_train.v05', 'rainfall_train.v06', 'rainfall_train.v07', 'rainfall_train.v08','rainfall_train.v09']
df1[num_col] = df1[num_col].apply(lambda x: x.clip(x.quantile(0.05), x.quantile(0.95)), axis=0)

# %%
# 데이터프레임 히스토그램 확인
df1.hist(bins = 50, figsize = (20,15))
plt.show()

# %%
# 스케일링
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df1[num_col] = scaler.fit_transform(df1[num_col])
df1
# Out:
#          rainfall_train.fc_month  rainfall_train.fc_day  \
# 0                              5                      1
# 1                              5                      1
# 2                              5                      1
# 3                              5                      1
# 4                              5                      1
# ...                          ...                    ...
# 1457247                        9                     30
# 1457248                        9                     30
# 1457249                        9                     30
# 1457250                        9                     30
# 1457251                        9                     30
#
#          rainfall_train.fc_hour  rainfall_train.dh  rainfall_train.ef_month  \
# 0                             9                  3                        5
# 1                             9                  6                        5
# ...

# %% [markdown]
# ### 새로운 변수 생성

# %%
def get_max_prob(row):
    return row.max()

# %%
# 새로운 변수 생성
df1['rainfall_train.sum'] = df1['rainfall_train.v02'] +  df1['rainfall_train.v03'] +  df1['rainfall_train.v04'] +  df1['rainfall_train.v05'] +  df1['rainfall_train.v06'] +  df1['rainfall_train.v07'] +  df1['rainfall_train.v08'] +  df1['rainfall_train.v09']
df1['rainfall_train.mean'] = (df1['rainfall_train.v02'] +  df1['rainfall_train.v03'] +  df1['rainfall_train.v04'] +  df1['rainfall_train.v05'] +  df1['rainfall_train.v06'] +  df1['rainfall_train.v07'] +  df1['rainfall_train.v08'] +  df1['rainfall_train.v09']) / 9
df1['rainfall_train.vv/dh'] = df1['rainfall_train.vv'] / df1['rainfall_train.dh'] # dh가 작을수록 정확하다고 여겨 가중치 부여
df1['max_prob'] = df1[['rainfall_train.v01', 'rainfall_train.v02', 'rainfall_train.v03', 'rainfall_train.v04', 'rainfall_train.v05', 'rainfall_train.v06', 'rainfall_train.v07', 'rainfall_train.v08', 'rainfall_train.v09']].apply(get_max_prob, axis=1) # 각 행에서 가장 큰 누적 확률 값

# %% [markdown]
# ### Feature_Selection

# %%
# 계급구간과의 상관계수 행렬
corr_df = df1.corr()['rainfall_train.class_interval'].drop('rainfall_train.class_interval')
corr_df = corr_df.apply(lambda x: round(x,2))
corr_df.sort_values(ascending=False)
# Out:
# rainfall_train.vv           0.70
# rainfall_train.v04          0.49
# rainfall_train.v05          0.48
# rainfall_train.mean         0.47
# rainfall_train.sum          0.47
# rainfall_train.v03          0.47
# rainfall_train.v06          0.45
# rainfall_train.v02          0.45
# rainfall_train.v01          0.42
# max_prob                    0.41
# rainfall_train.v07          0.39
# rainfall_train.vv/dh        0.31
# rainfall_train.v08          0.27
# rainfall_train.v09          0.20
# rainfall_train.fc_year_A    0.06
# rainfall_train.ef_year_A    0.06
# rainfall_train.ef_month     0.05
# rainfall_train.fc_month     0.04
# rainfall_train.fc_day       0.00
# rainfall_train.dh           0.00
# rainfall_train.fc_hour      0.00
# rainfall_train.ef_hour     -0.01
# rainfall_train.fc_year_B   -0.02
# rainfall_train.ef_year_B   -0.02
# rainfall_train.aws         -0.02
# rainfall_train.ef_day      -0.04
# rainfall_train.fc_year_C   -0.04
# rainfall_train.ef_year_C   -0.04
# ...

# %%
## 상관계수에 따른 가중치 부여? 4,5,3,6,2,1,7,8,9
# 스케일링 전 단계에 수행되어야 할 것 같음

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# SFS 전진, 후진, 단계선택법 저장
sfs_forward = SFS(model, k_features = 'best', forward = True, floating = False, scoring = 'accuracy', cv = 3)
sfs_backward = SFS(model, k_features = 'best', forward = False, floating = False, scoring = 'accuracy', cv = 3)
sfs_stepwise = SFS(model, k_features = 'best', forward = True, floating = True, scoring = 'accuracy', cv = 3)

# 데이터를 방법별로 학습
sfs_forward = sfs_forward.fit(X_train, y_train)
sfs_backward = sfs_backward.fit(X_train, y_train)
sfs_stepwise = sfs_stepwise.fit(X_train, y_train)

# 선택된 특성 출력 -> 어떤 피처들이 선정되는지 ?
print('sfs_forward 선택된 특성')
print(sfs_forward.k_feature_names_)

print('sfs_backward 선택된 특성')
print(sfs_backward.k_feature_names_)

print('sfs_stepwise 선택된 특성')
print(sfs_stepwise.k_feature_names_)

# 실제 어떤 식으로 변화하는지 시각화로 체크
fig, ax = plt.subplots(1,3, figsize=(18,6))
ax[0].plot(range(1, len(sfs_forward.subsets_)+1),[sfs_forward.subsets_[i]['avg_score'] for i in sfs_forward.subsets_], marker = 'o')
ax[0].set_title('sfs_forward')

ax[1].plot(range(1, len(sfs_backward.subsets_)+1),[sfs_backward.subsets_[i]['avg_score'] for i in sfs_backward.subsets_], marker = 'o')
ax[1].set_title('sfs_backward')

ax[2].plot(range(1, len(sfs_stepwise.subsets_)+1),[sfs_stepwise.subsets_[i]['avg_score'] for i in sfs_stepwise.subsets_], marker = 'o')
ax[2].set_title('sfs_stepwise')

plt.tight_layout()
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
# ...

# %% [markdown]
# ### CSI

# %%
def calculate_csi(df, predicted_col):
    # Hit (H): 예보가 정확히 맞아떨어진 경우
    hits = ((y_test == df[predicted_col]) & (y_test > 0)).sum()

    # False Alarm (F): 잘못된 예보의 수
    false_alarms = ((y_test != df[predicted_col]) & (df[predicted_col] > 0)).sum()

    # Miss (M): 놓친 예보의 수
    misses = ((y_test != df[predicted_col]) & (y_test > 0) & (df[predicted_col] == 0)).sum()

    # CSI 계산
    csi = hits / (hits + false_alarms + misses)

    return csi

# %% [markdown]
# ## 분류
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error

X = df1.drop(columns=['rainfall_train.vv', 'rainfall_train.class_interval'])
y = df1['rainfall_train.class_interval']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

dff = X_test.copy()
dff['rf'] = y_pred
csi_value = calculate_csi(dff, 'rf')

print(f'accuracy: {accuracy:.5f}')
print(f'CSI: {csi_value:.4f}')
# Out:
# accuracy: 0.97923
# CSI: 0.8670

# %% [markdown]
# ### LGBM

# %%
! pip install lightgbm
from lightgbm import LGBMClassifier

lgb = LGBMClassifier(
    num_iterations=200,
    learning_rate=0.1,
    max_depth=5,
    min_data_in_leaf=20,
    num_leaves=31,
    boosting='gbdt',
    bagging_fraction=1.0,
    feature_fraction=1.0,
    lambda_l1=0.0,
    lambda_l2=0.0,
    random_state=42
    )

lgb.fit(X_train, y_train)
y_pred = lgb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

dff['lgb'] = y_pred
csi_value = calculate_csi(dff, 'lgb')

print(f'accuracy: {accuracy:.5f}')
print(f'CSI: {csi_value:.4f}')
# Out:
# ...
#      ---------------------------------------- 1.4/1.4 MB 18.4 MB/s eta 0:00:00
# ...
# C:\Users\k0e1s\anaconda3\lib\site-packages\lightgbm\engine.py:204: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] lambda_l1 is set=0.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0
# [LightGBM] [Warning] lambda_l2 is set=0.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# ...

# %% [markdown]
# ## 회귀
# ### LinearRegression

# %%
from sklearn.linear_model import LinearRegression

X = df1.drop(columns=['rainfall_train.vv', 'rainfall_train.class_interval'])
y = df1['rainfall_train.vv']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['lr'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'lr')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 15>()
#      12 r2 = r2_score(y_test, y_pred)
#      13 mse = mean_squared_error(y_test, y_pred)
# ---> 15 dff['lr'] = np.round(y_pred, 1)
#      16 csi_value = calculate_csi(dff, 'lr')
#      18 print(f'R2: {r2:.5f}')
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge

rd = Ridge()
rd.fit(X_train, y_train)

y_pred = rd.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['rd'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'rd')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# R2: 0.23907
# MSE: 14.99859
# CSI: 0.00568

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

ls = Lasso()
ls.fit(X_train, y_train)

y_pred = ls.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['ls'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'ls')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# R2: 0.09532
# MSE: 17.83210
# CSI: 0.00449

# %% [markdown]
# ### ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet

en = ElasticNet(alpha = 0.1, l1_ratio=0.5)
en.fit(X_train, y_train)

y_pred = en.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['en'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'en')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# R2: 0.19054
# MSE: 15.95517
# CSI: 0.00540

# %% [markdown]
# ### DecisionTree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(max_depth=5, random_state=42)
dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['dt'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'dt')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# R2: 0.88674
# MSE: 2.23237
# CSI: 0.14375

# %% [markdown]
# ### ★ RandomForest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(random_state=42)
rfr.fit(X_train, y_train)

y_pred = rfr.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['rfr'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'rfr')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# R2: 0.99726
# MSE: 0.05403
# CSI: 0.92329

# %% [markdown]
# ### Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(random_state=42)
gbr.fit(X_train, y_train)

y_pred = gbr.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['gbr'] = np.round(y_pred, 1)
csi_value = calculate_csi(dff, 'gbr')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
# Out:
# R2: 0.99257
# MSE: 0.14640
# CSI: 0.12179

# %%
dff
# Out:
#          rainfall_train.fc_month  rainfall_train.fc_day  \
# 1105935                        8                      2
# 822758                         9                     27
# 592654                         7                     10
# 1368909                        6                     28
# 880067                         6                     22
# ...                          ...                    ...
# 459072                         9                     22
# 970794                         5                     14
# 1264936                        5                     21
# 613986                         6                     24
# 650737                         9                      9
#
#          rainfall_train.fc_hour  rainfall_train.dh  rainfall_train.ef_month  \
# 1105935                      21                225                        8
# 822758                       21                201                       10
# ...

# %%
# vv 를 class_interval로 변환

def classify(y):
    list = []
    for value in y:
        if value < 0.1:
            list.append(0)
        elif 0.1 <= value <= 0.19:
            list.append(1)
        elif 0.2 <= value <= 0.49:
            list.append(2)
        elif 0.5 <= value <= 0.99:
            list.append(3)
        elif 1.0 <= value <= 1.9:
            list.append(4)
        elif 2.0 <= value <= 4.9:
            list.append(5)
        elif 5.0 <= value <= 9.9:
            list.append(6)
        elif 10.0 <= value <= 19.9:
            list.append(7)
        elif 20.0 <= value <= 29.9:
            list.append(8)
        elif value >= 30.0:
            list.append(9)
        else:
            list.append(999)
    return list

# %%
rfr.fit(X_train, y_train)
y_test = classify(y_test)
y_pred = np.round(rfr.predict(X_test), 1)
y_pred = classify(y_pred)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

dff['rfr'] = y_pred
csi_value = calculate_csi(dff, 'rfr')

print(f'R2: {r2:.5f}')
print(f'MSE: {mse:.5f}')
print(f'CSI: {csi_value:.5f}')
